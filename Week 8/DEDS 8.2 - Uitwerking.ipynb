# %% [markdown]
# # Imports (Classificatie model)

# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn import metrics
import matplotlib.pyplot as plt                 
import sqlite3

# %% [markdown]
# ### Data inlezen en kolommen selecteren

# %%
con_sales = sqlite3.connect("go_sales.sqlite")
con_sales

# %% [markdown]
# ### Relevante dataframes aanmaken

# %%
sql_query1 = "SELECT * FROM RETURNED_ITEM;"
return_df = pd.read_sql(sql_query1, con_sales)

sql_query2 = "SELECT * FROM ORDER_DETAILS;"
order_df = pd.read_sql(sql_query2, con_sales)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\AdvancedGaming\AppData\Local\pypoetry\Cache\virtualenvs\deds-AWrnpz_V-py3.12\Lib\site-packages\pandas\io\sql.py:2675, in SQLiteDatabase.execute(self, sql, params)
#    2674 try:
# -> 2675     cur.execute(sql, *args)
#    2676     return cur
#
# OperationalError: no such table: RETURNED_ITEM
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[14], line 2
#       1 sql_query1 = "SELECT * FROM RETURNED_ITEM;"
# ----> 2 return_df = pd.read_sql(sql_query1, con_sales)
#       4 sql_query2 = "SELECT * FROM ORDER_DETAILS;"
#       5 order_df = pd.read_sql(sql_query2, con_sales)
#
# ...

# %% [markdown]
# ### Return reason en order details samenvoegen

# %%
join_df = pd.merge(return_df, order_df, left_on = 'ORDER_DETAIL_CODE', how = 'outer', right_on="ORDER_DETAIL_CODE")
join_df
# Out:
#       RETURN_CODE RETURN_DATE ORDER_DETAIL_CODE RETURN_REASON_CODE  \
# 0             NaN         NaN            100000                NaN
# 1             NaN         NaN            100001                NaN
# 2             NaN         NaN            100002                NaN
# 3             NaN         NaN            100003                NaN
# 4             NaN         NaN            100004                NaN
# ...           ...         ...               ...                ...
# 43058         NaN         NaN             99995                NaN
# 43059         NaN         NaN             99996                NaN
# 43060         NaN         NaN             99997                NaN
# 43061         NaN         NaN             99998                NaN
# 43062         NaN         NaN             99999                NaN
#
#       RETURN_QUANTITY TRIAL888 ORDER_NUMBER PRODUCT_NUMBER  QUANTITY  \
# 0                 NaN      NaN         8462             96        16
# ...

# %% [markdown]
# ### Juiste kolommen selecteren in de samengevoegde dataframe

# %%
join_df = join_df.loc[:, []]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 join_df = join_df.loc[:, []]
#
# NameError: name 'join_df' is not defined
